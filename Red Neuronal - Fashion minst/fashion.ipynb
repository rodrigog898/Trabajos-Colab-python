# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Cargar los datos de Fashion-MNIST
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Preprocesamiento de los datos
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Definir la arquitectura del modelo
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compilar el modelo
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Entrenar el modelo
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Evaluar el modelo en el conjunto de prueba
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nPrecisión en el conjunto de prueba:', test_acc)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 938/938 [==============================] - 63s 66ms/step - loss: 0.5597 - accuracy: 0.7936 - val_loss: 0.3996 - val_accuracy: 0.8588
# Epoch 2/10
# 938/938 [==============================] - 57s 61ms/step - loss: 0.3467 - accuracy: 0.8742 - val_loss: 0.3339 - val_accuracy: 0.8781
# Epoch 3/10
# 938/938 [==============================] - 60s 64ms/step - loss: 0.2980 - accuracy: 0.8921 - val_loss: 0.2993 - val_accuracy: 0.8938
# Epoch 4/10
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2655 - accuracy: 0.9026 - val_loss: 0.2854 - val_accuracy: 0.8957
# Epoch 5/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Cargar los datos de Fashion-MNIST
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Preprocesamiento de los datos
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Definir la arquitectura del modelo
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compilar el modelo
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Entrenar el modelo
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Evaluar el modelo en el conjunto de prueba
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nPrecisión en el conjunto de prueba:', test_acc)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 46s 47ms/step - loss: 0.5586 - accuracy: 0.7936 - val_loss: 0.4135 - val_accuracy: 0.8514
# Epoch 2/10
# 938/938 [==============================] - 49s 53ms/step - loss: 0.3576 - accuracy: 0.8704 - val_loss: 0.3462 - val_accuracy: 0.8738
# Epoch 3/10
# 938/938 [==============================] - 44s 47ms/step - loss: 0.3058 - accuracy: 0.8896 - val_loss: 0.3371 - val_accuracy: 0.8754
# Epoch 4/10
# 938/938 [==============================] - 46s 49ms/step - loss: 0.2742 - accuracy: 0.8992 - val_loss: 0.2986 - val_accuracy: 0.8912
# Epoch 5/10
# 938/938 [==============================] - 43s 46ms/step - loss: 0.2469 - accuracy: 0.9092 - val_loss: 0.2890 - val_accuracy: 0.8943
# Epoch 6/10
# 938/938 [==============================] - 44s 47ms/step - loss: 0.2294 - accuracy: 0.9151 - val_loss: 0.2797 - val_accuracy: 0.8999
# Epoch 7/10
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Cargar los datos de Fashion-MNIST
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Preprocesamiento de los datos
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1)) 
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)) 
x_train = x_train.astype('float32') / 255 
x_test = x_test.astype('float32') / 255 

# Definir la arquitectura del modelo
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compilar el modelo
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Obtener las métricas durante el entrenamiento
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# Graficar las métricas
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 938/938 [==============================] - 78s 78ms/step - loss: 0.5591 - accuracy: 0.7955 - val_loss: 0.4005 - val_accuracy: 0.8593
# Epoch 2/10
# 574/938 [=================>............] - ETA: 25s - loss: 0.3612 - accuracy: 0.8685
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-efaceaa5edc4> in <cell line: 33>()
#      31
#      32 # Entrenar el modelo
# ---> 33 history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
#      34
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Cargar los datos de Fashion-MNIST
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Preprocesamiento de los datos
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1)) 
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)) 
x_train = x_train.astype('float32') / 255 
x_test = x_test.astype('float32') / 255 

# Definir la arquitectura del modelo
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compilar el modelo
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Obtener las métricas durante el entrenamiento
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# Graficar las métricas
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Guardar el modelo entrenado
model.save('fashion_mnist_model.h5')

# Cargar el modelo guardado
loaded_model = tf.keras.models.load_model('fashion_mnist_model.h5')

# Evaluar el modelo cargado en los datos de prueba
loss, accuracy = loaded_model.evaluate(x_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 938/938 [==============================] - 74s 74ms/step - loss: 0.5605 - accuracy: 0.7947 - val_loss: 0.3980 - val_accuracy: 0.8571
# Epoch 2/10
# 938/938 [==============================] - 61s 65ms/step - loss: 0.3488 - accuracy: 0.8737 - val_loss: 0.3325 - val_accuracy: 0.8787
# Epoch 3/10
# 938/938 [==============================] - 59s 63ms/step - loss: 0.3028 - accuracy: 0.8883 - val_loss: 0.3155 - val_accuracy: 0.8879
# Epoch 4/10
# 938/938 [==============================] - 63s 67ms/step - loss: 0.2678 - accuracy: 0.9025 - val_loss: 0.2917 - val_accuracy: 0.8943
# Epoch 5/10
# ...

# %%
import numpy as np

# Seleccionar una muestra del conjunto de prueba para probar el modelo
sample_index = 0
sample_image = x_test[sample_index]
sample_label = y_test[sample_index]

# Agregar una dimensión adicional para que coincida con el formato de entrada del modelo
sample_image = np.expand_dims(sample_image, axis=0)

# Realizar la predicción con el modelo
predictions = model.predict(sample_image)

# Obtener la clase predicha
predicted_label = np.argmax(predictions)

# Imprimir los resultados
print('Etiqueta verdadera:', sample_label)
print('Etiqueta predicha:', predicted_label)
# Out:
# 1/1 [==============================] - 0s 107ms/step
# Etiqueta verdadera: 9
# Etiqueta predicha: 9

# %%
import numpy as np
import matplotlib.pyplot as plt

# Seleccionar una muestra del conjunto de prueba para probar el modelo
sample_index = 0
sample_image = x_test[sample_index]
sample_label = y_test[sample_index]

# Agregar una dimensión adicional para que coincida con el formato de entrada del modelo
sample_image = np.expand_dims(sample_image, axis=0)

# Realizar la predicción con el modelo
predictions = model.predict(sample_image)

# Obtener la clase predicha
predicted_label = np.argmax(predictions)

# Definir la lista de etiquetas de Fashion-MNIST
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Mostrar la imagen de prueba
plt.imshow(sample_image.squeeze(), cmap='gray')
plt.title('Etiqueta verdadera: {}\nEtiqueta predicha: {}'.format(class_names[sample_label], class_names[predicted_label]))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import requests
from PIL import Image
import numpy as np

# Cargar el modelo pre-entrenado
model = tf.keras.applications.ResNet50(weights='imagenet')

# URL de la imagen que deseas probar
image_url = 'https://falabella.scene7.com/is/image/Falabella/50020730_01?wid=800&hei=800&qlt=70'

# Descargar la imagen desde la URL
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Redimensionar la imagen a las dimensiones requeridas por el modelo
img = img.resize((224, 224))

# Convertir la imagen a un arreglo numpy
img_array = image.img_to_array(img)

# Expandir las dimensiones para que coincida con el formato de entrada del modelo
img_array = np.expand_dims(img_array, axis=0)

# Preprocesar la imagen
img_array = preprocess_input(img_array)

# Realizar la predicción con el modelo
preds = model.predict(img_array)

# Decodificar las predicciones
decoded_preds = decode_predictions(preds, top=3)[0]

# Imprimir las predicciones
for pred in decoded_preds:
    print(pred[1], ": ", pred[2])
# Out:
# ...
# 102967424/102967424 [==============================] - 1s 0us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fcea3b61b605> in <cell line: 16>()
#      14 # Descargar la imagen desde la URL
#      15 response = requests.get(image_url)
# ---> 16 img = Image.open(BytesIO(response.content))
#      17
#      18 # Redimensionar la imagen a las dimensiones requeridas por el modelo
#
# NameError: name 'BytesIO' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import requests
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo pre-entrenado
model = tf.keras.applications.ResNet50(weights='imagenet')

# URL de la imagen que deseas probar
image_url = 'https://falabella.scene7.com/is/image/Falabella/50020730_01?wid=800&hei=800&qlt=70'

# Descargar la imagen desde la URL
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Redimensionar la imagen a las dimensiones requeridas por el modelo
img = img.resize((224, 224))

# Convertir la imagen a un arreglo numpy
img_array = image.img_to_array(img)

# Expandir las dimensiones para que coincida con el formato de entrada del modelo
img_array = np.expand_dims(img_array, axis=0)

# Preprocesar la imagen
img_array = preprocess_input(img_array)

# Realizar la predicción con el modelo
preds = model.predict(img_array)

# Decodificar las predicciones
decoded_preds = decode_predictions(preds, top=1)[0]
category = decoded_preds[0][1]
probability = decoded_preds[0][2]

# Mostrar la imagen
plt.imshow(img)
plt.title('Categoría: {}\nProbabilidad: {:.2f}%'.format(category, probability*100))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import requests
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo pre-entrenado
model = tf.keras.applications.ResNet50(weights='imagenet')

# URL de la imagen que deseas probar
image_url = 'https://cdn.shopify.com/s/files/1/1213/3044/products/NOWECOM15.02-258_1024x1024.jpg?v=1678198805'

# Descargar la imagen desde la URL
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Redimensionar la imagen a las dimensiones requeridas por el modelo
img = img.resize((224, 224))

# Convertir la imagen a un arreglo numpy
img_array = image.img_to_array(img)

# Expandir las dimensiones para que coincida con el formato de entrada del modelo
img_array = np.expand_dims(img_array, axis=0)

# Preprocesar la imagen
img_array = preprocess_input(img_array)

# Realizar la predicción con el modelo
preds = model.predict(img_array)

# Decodificar las predicciones
decoded_preds = decode_predictions(preds, top=1)[0]
category = decoded_preds[0][1]
probability = decoded_preds[0][2]

# Mostrar la imagen
plt.imshow(img)
plt.title('Categoría: {}\nProbabilidad: {:.2f}%'.format(category, probability*100))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import requests
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo pre-entrenado
model = tf.keras.applications.ResNet50(weights='imagenet')

# URL de la imagen que deseas probar
image_url = 'https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcSmzTfyk_kt9bmEKSxj9IdkbKLoYI42IMifqMJAEz5x74WC6V2QDyefQhMO3MO6XnJ4aW06tk3V7WpgZ-1AliNqYbQ-QWt2zMCipR2G63FEj8HFaAsbPnow3w&usqp=CAE'

# Descargar la imagen desde la URL
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Redimensionar la imagen a las dimensiones requeridas por el modelo
img = img.resize((224, 224))

# Convertir la imagen a un arreglo numpy
img_array = image.img_to_array(img)

# Expandir las dimensiones para que coincida con el formato de entrada del modelo
img_array = np.expand_dims(img_array, axis=0)

# Preprocesar la imagen
img_array = preprocess_input(img_array)

# Realizar la predicción con el modelo
preds = model.predict(img_array)

# Decodificar las predicciones
decoded_preds = decode_predictions(preds, top=1)[0]
category = decoded_preds[0][1]
probability = decoded_preds[0][2]

# Mostrar la imagen
plt.imshow(img)
plt.title('Categoría: {}\nProbabilidad: {:.2f}%'.format(category, probability*100))
plt.axis('off')
plt.show()
# Out:
# ...
# 102967424/102967424 [==============================] - 1s 0us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2d2214ed3f04> in <cell line: 17>()
#      15 # Descargar la imagen desde la URL
#      16 response = requests.get(image_url)
# ---> 17 img = Image.open(BytesIO(response.content))
#      18
#      19 # Redimensionar la imagen a las dimensiones requeridas por el modelo
#
# NameError: name 'BytesIO' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import requests
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
# Cargar el modelo pre-entrenado
model = tf.keras.applications.ResNet50(weights='imagenet')

# URL de la imagen que deseas probar
image_url = 'https://hmchile.vtexassets.com/arquivos/ids/5052578-483-725/Mom-Comfort-Ultra-High-Jeans---Azul-denim---H-M-CL.jpg?v=638119503297030000'

# Descargar la imagen desde la URL
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Redimensionar la imagen a las dimensiones requeridas por el modelo
img = img.resize((224, 224))

# Convertir la imagen a un arreglo numpy
img_array = image.img_to_array(img)

# Expandir las dimensiones para que coincida con el formato de entrada del modelo
img_array = np.expand_dims(img_array, axis=0)

# Preprocesar la imagen
img_array = preprocess_input(img_array)

# Realizar la predicción con el modelo
preds = model.predict(img_array)

# Decodificar las predicciones
decoded_preds = decode_predictions(preds, top=1)[0]
category = decoded_preds[0][1]
probability = decoded_preds[0][2]

# Mostrar la imagen
plt.imshow(img)
plt.title('Categoría: {}\nProbabilidad: {:.2f}%'.format(category, probability*100))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
